# %% [markdown]
# Project 1
# SONAR Rock vs Mine Prediction with Python
#
# Rock vs Mine
#
# Consider there is a Submarine. There is a war going between two countries. Submarine of a country is going to another country and the enemy country has planted some underwater mines
# and explosives that explodes whenever an object comes near it. But they can also be rocks in the ocean. So the Submarine Captain has to
# predict whether it is MINE or ROCK.
# Job is to make a system that predicts the object beneath the submarine is rock or a mine.
# submarine sends a sonar signal.(Sound signal)
#
# Work Flow
# 1. Collect the sonar data
# in the laboratory system a experiment is to be done that sonar data is used to send and receive signals from metal cylinders and some rocks.
# we feed the sonar learnig data to our machine learnig model, then it can predict whether the object is made up of metal or just a rock.
#
# 2. Data Pre Processing
# data Harvestion
#
# 3. Training and testing data
#
# 4. Logistic Regression model (Binary Classification model) (Supervised learnig)
#
# 5. Trained Logistic Regression model
#
# new data -> Prediction
